# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
df=pd.read_csv("boston.csv")
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  MEDV
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       506 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# MEDV       0
# dtype: int64

# %%
df.mean()
# Out:
# crim         3.613524
# zn          11.363636
# indus       11.136779
# chas         0.069170
# nox          0.554695
# rm           6.284634
# age         68.574901
# dis          3.795043
# rad          9.549407
# tax        408.237154
# ptratio     18.455534
# b          356.674032
# lstat       12.653063
# MEDV        22.532806
# dtype: float64

# %%
df.std()
# Out:
# crim         8.601545
# zn          23.322453
# indus        6.860353
# chas         0.253994
# nox          0.115878
# rm           0.702617
# age         28.148861
# dis          2.105710
# rad          8.707259
# tax        168.537116
# ptratio      2.164946
# b           91.294864
# lstat        7.141062
# MEDV         9.197104
# dtype: float64

# %%
X=df.drop('MEDV',axis=1)
y=df['MEDV']

# %%
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#          crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 39    0.02763  75.0   2.95     0  0.428  6.595  21.8  5.4011    3  252
# 45    0.17142   0.0   6.91     0  0.448  5.682  33.8  5.1004    3  233
# 32    1.38799   0.0   8.14     0  0.538  5.950  82.0  3.9900    4  307
# 395   8.71675   0.0  18.10     0  0.693  6.471  98.8  1.7257   24  666
# 394  13.35980   0.0  18.10     0  0.693  5.887  94.7  1.7821   24  666
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 479  14.33370   0.0  18.10     0  0.614  6.229  88.0  1.9512   24  666
# 314   0.36920   0.0   9.90     0  0.544  6.567  87.3  3.6023    4  304
# 430   8.49213   0.0  18.10     0  0.584  6.348  86.1  2.0527   24  666
# 247   0.19657  22.0   5.86     0  0.431  6.226  79.2  8.0555    7  330
# 222   0.62356   0.0   6.20     1  0.507  6.879  77.7  3.2721    8  307
#
#      ptratio       b  lstat
# 39      18.3  395.63   4.32
# 45      17.9  396.90  10.21
# ...

# %%
scaler=MinMaxScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.fit_transform(X_test)

# %%
print("Shape Of X Train Scaled:",X_train_scaled.shape)
# Out:
# Shape Of X Train Scaled: (354, 13)

# %%
print("Shape Of X Test scaled:",X_test_scaled.shape)
# Out:
# Shape Of X Test scaled: (152, 13)

# %%
X_train_scaled[0]
# Out:
# array([2.39519262e-04, 7.50000000e-01, 9.12756598e-02, 0.00000000e+00,
#        8.84773663e-02, 5.89928058e-01, 1.68085106e-01, 3.88015833e-01,
#        8.69565217e-02, 1.24045802e-01, 6.06382979e-01, 9.96779756e-01,
#        7.14679912e-02])

# %%
X_train_scaled[47]
# Out:
# array([0.01637678, 0.        , 0.70087977, 0.        , 0.4526749 ,
#        0.76375656, 0.90212766, 0.07588152, 0.17391304, 0.41221374,
#        0.22340426, 0.94302449, 0.        ])

# %%
X_train_scaled[0].shape
# Out:
# (13,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *

# %%
model=Sequential()

# %%
model.add(Dense(128,activation="relu",input_shape=(X_train_scaled[0].shape)))
model.add(Dense(64,activation="relu"))
model.add(Dense(32,activation="relu"))
model.add(Dense(16,activation="relu"))
model.add(Dense(1))

# %%
model.compile(optimizer="adam",loss="mse",metrics=["mae"])

# %%
history=model.fit(X_train_scaled,y_train,batch_size=1,epochs=10,validation_data=(X_test_scaled,y_test))
# Out:
# Epoch 1/10
# 354/354 [==============================] - 3s 4ms/step - loss: 151.4094 - mae: 8.8545 - val_loss: 50.5709 - val_mae: 4.6672
# Epoch 2/10
# 354/354 [==============================] - 1s 3ms/step - loss: 39.0225 - mae: 4.4409 - val_loss: 33.5703 - val_mae: 3.8978
# Epoch 3/10
# 354/354 [==============================] - 1s 3ms/step - loss: 26.5620 - mae: 3.5424 - val_loss: 44.9951 - val_mae: 5.2474
# Epoch 4/10
# 354/354 [==============================] - 1s 3ms/step - loss: 22.2889 - mae: 3.4053 - val_loss: 26.2784 - val_mae: 3.6228
# Epoch 5/10
# 354/354 [==============================] - 1s 3ms/step - loss: 20.6461 - mae: 3.2383 - val_loss: 23.3877 - val_mae: 3.2623
# Epoch 6/10
# 354/354 [==============================] - 1s 3ms/step - loss: 17.9416 - mae: 2.9650 - val_loss: 25.0510 - val_mae: 3.4712
# Epoch 7/10
# 354/354 [==============================] - 1s 3ms/step - loss: 18.5271 - mae: 2.9955 - val_loss: 21.3329 - val_mae: 2.9571
# Epoch 8/10
# ...

# %%
test_input=[[0.01637678, 0.        , 0.70087977, 0.        , 0.4526749 ,
       0.76375656, 0.90212766, 0.07588152, 0.17391304, 0.41221374,
       0.22340426, 0.94302449, 0.        ]]
print("actual output",21.6)
print("predicted output:",model.predict(test_input))
# Out:
# actual output 21.6
# 1/1 [==============================] - 0s 43ms/step
# predicted output: [[48.02759]]

# %%
import matplotlib.pyplot as plt

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# prompt: prediction time and training time

import time

# Start timer
start_time = time.time()

# Train the model
model.fit(X_train_scaled, y_train, batch_size=1, epochs=10, validation_data=(X_test_scaled, y_test))

# End timer and compute elapsed time
end_time = time.time()
elapsed_time = end_time - start_time

# Predict on a test input
test_input = [[0.01637678, 0.        , 0.70087977, 0.        , 0.4526749 ,
       0.76375656, 0.90212766, 0.07588152, 0.17391304, 0.41221374,
       0.22340426, 0.94302449, 0.        ]]

# Start timer
start_time_prediction = time.time()

# Predict on the test input
model.predict(test_input)

# End timer and compute elapsed time for prediction
end_time_prediction = time.time()
elapsed_time_prediction = end_time_prediction - start_time_prediction

# Print training time and prediction time
print("Training time:", elapsed_time, "seconds")
print("Prediction time:", elapsed_time_prediction, "seconds")
